# %% [markdown]
# <a href="https://colab.research.google.com/github/arssite/MachineLearning/blob/main/LinearRegression_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['YearsExperience'].plot(kind='hist', bins=20, title='YearsExperience')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Salary'].plot(kind='hist', bins=20, title='Salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='YearsExperience', y='Salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.shape
# Out:
# (30, 2)

# %%
data.iloc[0:5]
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
x=data[['YearsExperience']]#input
#.values for output in array else come in series
y=data['Salary'].values#output
print(x,'\n',y)
# Out:
#     YearsExperience
# 0               1.1
# 1               1.3
# 2               1.5
# 3               2.0
# 4               2.2
# 5               2.9
# 6               3.0
# 7               3.2
# 8               3.2
# 9               3.7
# 10              3.9
# 11              4.0
# 12              4.0
# 13              4.1
# 14              4.5
# 15              4.9
# 16              5.1
# 17              5.3
# 18              5.9
# 19              6.0
# 20              6.8
# 21              7.1
# 22              7.9
# 23              8.2
# 24              8.7
# 25              9.0
# 26              9.5
# 27              9.6
# 28             10.3
# 29             10.5
#  [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
#ALternate Way
'''
x=data.iloc[:,:-1].values.reshape(len(data),1)
y=data.iloc[:,-1].values
print(x,'\n',y)

'''
# Out:
# "\nx=data.iloc[:,:-1].values.reshape(len(data),1)\ny=data.iloc[:,-1].values\nprint(x,'\n',y)\n"

# %%
#splitting
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)#if train_size=0.8
#The random_state parameter in the train_test_split function is used to control the shuffling process that happens before splitting the data into training and testing sets. Setting random_state to a fixed value (like 0 in your code) ensures that you will get the same split every time you run the code, making your results reproducible.
#If you don't set a value, a random number generator is used, and the split will be different each time.

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
#model.LinearRegression()
# Out:
# LinearRegression()

# %% [markdown]
# The main difference between fit (train on given data)and fit_transform (scaling) lies in their purpose and the kind of objects they operate on.
#
# **fit:**
#
# Used for training a machine learning model on the provided data (e.g., x_train, y_train).
# Learns the parameters of the model (like coefficients in linear regression) based on the training data.
#
# **fit_transform:**
#
# Typically used with transformers (objects that preprocess data, like scalers or encoders).
# It performs two actions:
# fit: Learns the necessary parameters from the training data (e.g., mean and standard deviation for a scaler).
# transform: Applies the learned transformation to the data (e.g., scaling the data).

# %%
ypred=model.predict(x_test)

# %%
ypred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
#Error
#from sklearn.metrics import mean_absolute_error
from sklearn  import metrics
import numpy as np
print('MAE: ',metrics.mean_absolute_error(y_test,ypred))
print('MSE: ',metrics.mean_squared_error(y_test,ypred))
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y_test,ypred)))
# Out:
# MAE:  2446.1723690465055
# MSE:  12823412.298126549
# RMSE:  3580.979237321343

# %%
#R2 score is Accuracy as 1-Rsq
print('R2 score: ',metrics.r2_score(y_test,ypred))
# Out:
# R2 score:  0.988169515729126

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='red',label='Actual',s=80)
plt.scatter(x_train,model.predict(x_train),color='green',label='Predicted',s=80)
plt.plot(x_train,model.predict(x_train),color='blue',lw=3,label="Line Of Regression")
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
#Testing

import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='red',label='Actual',s=80)
plt.scatter(x_test,model.predict(x_test),color='green',label='Predicted',s=80)
plt.plot(x_test,model.predict(x_test),color='blue',lw=3,label="Line Of Regression")
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
model.intercept_
# Out:
# 26780.09915062818

# %%
accuracy=[]
for i in range(501):
  xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=i)
  model1=LinearRegression()
  model1.fit(xtrain,ytrain)
  ypred1=model1.predict(xtest)
  accuracy.append(metrics.r2_score(ytest,ypred1))

# %%
print(np.max(accuracy))
print(np.argmax(accuracy))
accuracy
# Out:
# 0.9952429110093546
# 200
# [0.988169515729126,
#  0.7616681465472094,
#  0.8886956733784563,
#  0.9695039421049821,
#  0.9504404484884267,
#  0.9439628569611376,
#  0.9368146227107087,
#  0.8143022783109006,
#  0.9631182154839476,
#  0.9388416537799072,
#  0.9816423482070253,
#  0.940882728477622,
#  0.9429269163491423,
#  0.9394460269118793,
#  0.9606215790278543,
#  0.8697012433817218,
#  0.7949890249259297,
#  0.9384744808306155,
#  0.8864330645841889,
#  0.9415531751862448,
#  0.9441299149555877,
#  0.9398582853702572,
#  0.8870702615446784,
#  0.9184170849214232,
#  0.9520702017424296,
#  0.9531732818427658,
#  0.9835849730044816,
#  0.9636425773684423,
#  0.9217841352107623,
#  0.9467172742609803,
#  0.9944092048209745,
#  0.8967649524853983,
#  0.8985995727228404,
#  0.9350785573211586,
#  0.9244141448042442,
#  0.8839476512584652,
#  0.955021106900739,
#  0.9778242092591888,
#  0.972479448737762,
#  0.9928344802911048,
#  0.7775083459037234,
#  0.9802519469633169,
# ...

# %%
model.predict([[15]])[0]
# Out:
# 166468.72605156602

# %%
def salary():
  inp=float(input("Enter the experience: "))
  print("Salary :",model.predict([[inp]])[0])
  #print("RoundOFF",str(round(model.predict([[inp]])[0]),2))

# %%
salary()
# Out:
# Enter the experience: 5
# Salary : 73342.97478427412

# %%
import joblib
joblib.dump(model,'salary.pkl')
# Out:
# ['salary.pkl']

# %%
mymodelcall=joblib.load('salary.pkl')

# %%
round(mymodelcall.predict([[15]])[0],2)
# Out:
# 166468.73
